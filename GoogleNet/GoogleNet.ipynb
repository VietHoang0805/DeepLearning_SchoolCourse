# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

def inception_module(x, base_channels=32):
  a = Conv2D(base_channels*2, 1, 1, activation='relu')(x)

  b_1 = Conv2D(base_channels*2, 1, 1, activation='relu')(x)
  b_2 = Conv2D(base_channels*4, 3, 1, padding='same', activation='relu')(b_1)

  c_1 = Conv2D(base_channels, 1, 1, activation='relu')(x)
  c_2 = Conv2D(base_channels, 5, 1, padding='same', activation='relu')(c_1)

  d_1 = MaxPooling2D(3, 1, padding='same')(x)
  d_2 = Conv2D(base_channels, 1, 1, activation='relu')(d_1)

  return Concatenate(axis=-1)([a, b_2, c_2, d_2])

inp = Input((224, 224, 3))

maps_1 = inception_module(inp)
maps_2 = inception_module(maps_1, base_channels=16)

gap = GlobalAveragePooling2D()(maps_2)

output = Dense(1, activation='sigmoid')(gap)

model = Model(inputs=inp, outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 32  128         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 224, 224, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 12  73856       ['conv2d_1[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 32  25632       ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 224, 224, 32  128         ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 224, 224, 25  0           ['conv2d[0][0]',
#                                 6)                                'conv2d_2[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 32  8224        ['concatenate[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 224, 224, 16  4112        ['concatenate[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 224, 224, 25  0          ['concatenate[0][0]']
#                                 6)
#
#  conv2d_6 (Conv2D)              (None, 224, 224, 32  8224        ['concatenate[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 224, 224, 64  18496       ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 224, 224, 16  6416        ['conv2d_9[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 224, 224, 16  4112        ['max_pooling2d_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_6[0][0]',
#                                 8)                                'conv2d_8[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['concatenate_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1)            129         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 149,969
# Trainable params: 149,969
# Non-trainable params: 0
# __________________________________________________________________________________________________
